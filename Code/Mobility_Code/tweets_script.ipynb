# %%
import pandas as pd
import numpy as np
import glob,os
from functools import reduce

path=r'../Raw_data/Tweets/'
file=glob.glob(os.path.join(path, "*.csv"))

dl= []
col_name=['gram']

for f in file:
    dfi = pd.read_csv(f)
    dl.append(dfi)
    s = f[24:].split("_")
    col_name.append(s[0])


df_final = reduce(lambda left,right: pd.merge(left,right,on='gram', how='outer'), dl)
df_final.columns = col_name
df_final.set_index('gram',inplace=True)
df_final.to_csv("../Output/Tweets_Result/tweets_clean.csv")
df_final
# Out:
#                          04-18     04-15     04-05     04-08     04-25  \
# gram
# covid 19              157083.0  181560.0  134274.0  162077.0  173320.0
# coronavirus pandemic    8529.0   10956.0    8441.0   11052.0    8691.0
# coronavirus covid19     7032.0    9374.0    8433.0   10276.0    7659.0
# covid19 coronavirus     5836.0    9246.0    5930.0    9196.0    6256.0
# coronavirus cases       5389.0    4423.0    4457.0    4141.0    4960.0
# ...                        ...       ...       ...       ...       ...
# new twist                  NaN       NaN       NaN       NaN       NaN
# american blood             NaN       NaN       NaN       NaN       NaN
# prueba coronavirus         NaN       NaN       NaN       NaN       NaN
# fight virus                NaN       NaN       NaN       NaN       NaN
# of care                    NaN       NaN       NaN       NaN       NaN
#
#                         03-24     03-29     03-27     04-06     04-16  ...  \
# gram                                                                   ...
# covid 19              85876.0  110352.0  125985.0  154076.0  198348.0  ...
# coronavirus pandemic   5863.0    6957.0    8305.0    9334.0   10622.0  ...
# coronavirus covid19    4353.0    7559.0    9686.0    9499.0    9418.0  ...
# covid19 coronavirus    3175.0    5086.0    6445.0    7227.0    9212.0  ...
# coronavirus cases      3318.0    4757.0    5891.0    4363.0    4340.0  ...
# ...                       ...       ...       ...       ...       ...  ...
# new twist                 NaN       NaN       NaN       NaN       NaN  ...
# american blood            NaN       NaN       NaN       NaN       NaN  ...
# prueba coronavirus        NaN       NaN       NaN       NaN       NaN  ...
# fight virus               NaN       NaN       NaN       NaN       NaN  ...
# of care                   NaN       NaN       NaN       NaN       NaN  ...
#
#                          03-26     04-17     04-07     04-04     04-09  \
# gram
# covid 19              120843.0  176204.0  157280.0  137354.0  173752.0
# coronavirus pandemic    8595.0    9716.0   10013.0    8021.0   10067.0
# coronavirus covid19     8432.0    8920.0   10167.0    9072.0    8398.0
# covid19 coronavirus     6059.0    7933.0    9777.0    6668.0    6650.0
# coronavirus cases       6957.0    4407.0    3665.0    4512.0    4596.0
# ...                        ...       ...       ...       ...       ...
# new twist                  NaN       NaN       NaN       NaN       NaN
# american blood             NaN       NaN       NaN       NaN       NaN
# prueba coronavirus         NaN       NaN       NaN       NaN       NaN
# fight virus                NaN       NaN       NaN       NaN       NaN
# of care                    NaN       NaN       NaN       NaN       NaN
#
#                          04-19     04-14     04-24    03-25     03-28
# gram
# covid 19              170601.0  188072.0  179966.0  85937.0  109444.0
# coronavirus pandemic    8677.0   12028.0    9836.0   5402.0    6811.0
# coronavirus covid19     8846.0   10294.0    8038.0   4057.0    7669.0
# covid19 coronavirus     8149.0    9407.0    6947.0   2753.0    5994.0
# coronavirus cases       5325.0    4525.0    3800.0   3044.0    4816.0
# ...                        ...       ...       ...      ...       ...
# new twist                  NaN       NaN       NaN      NaN     241.0
# american blood             NaN       NaN       NaN      NaN     240.0
# prueba coronavirus         NaN       NaN       NaN      NaN     240.0
# fight virus                NaN       NaN       NaN      NaN     240.0
# of care                    NaN       NaN       NaN      NaN     240.0
#
# [7463 rows x 35 columns]
